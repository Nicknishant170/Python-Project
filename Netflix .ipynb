# %%
# Importing Data Set
#import python libraries

import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Aviral\Downloads\Python Project\First Data\Netflix Dataset.csv')

# %%
# to show all information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  Data_N        7779 non-null   datetime64[ns]
#  12  Date_N        7779 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), object(11)
# memory usage: 791.2+ KB

# %%
# To shows no. of rows and column 
df.shape
# Out:
# (7789, 13)

# %%
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.head() #default it shows top 5 records
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.tail() #default shows Bottom records
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country Release_Date Rating  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# ...

# %%
# To shows  no. of  Total Values (elements) in Data Set 
df.size
# Out:
# 101257

# %%
# To Shows Columns name
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Data_N',
#        'Date_N'],
#       dtype='object')

# %%
# To Show Data types
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
# TASK 1 : Is there any Duplicate Record in the dataset ? If yes the remove  duplicate records
#A
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#B
df.shape
# Out:
# (7789, 11)

# %%
# To detect row wise and Duplicate rows
#C
df.duplicated() #It will Show answer in Boolean
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Length: 7789, dtype: bool

# %%
#If you want to see the dataset then 
#D
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6300     5-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622     4-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description     Data_N     Date_N
# 6300  When two would-be robbers accidentally kill a ... 2019-04-05 2019-04-05
# 6622  A disillusioned security guard transforms into... 2020-09-04 2020-09-04

# %%
#To remove duplicate records permanently
#E
df.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#this is temporary so to make above changes permanent
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Data_N, Date_N]
# Index: []

# %%
#OR 
df.shape 
#so now duplicate values are removed permanently
# Out:
# (7787, 13)

# %%
#TASK 2: Is there any Null Values present in columns ?Show Heat Map
#A   is Null function
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
#B.  To show count of null values present in each column
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#To use Heat Map we need to use Seaborn Library 
#C.
import seaborn as sns    #seaborn library
#Using heatmap to show Null Values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Question1. For 'House of Card',what is the Show ID and Who is the Director of this Show ? 

#isin() function 
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#To show all record of particular item in any column
#1.
df['Title'].isin(['House of Cards'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
#2. 
df[df['Title'].isin(['House of Cards'])]

#Now we can show what is the Show ID & Director from below records
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# To check str.contains()
df['Title'].str.contains('House of Cards')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Title, Length: 7787, dtype: bool

# %%
#to get in desired in string in amy column 
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#Question 2: In which year highest number of TV Shows and Movies released ? Show with Bar graph
df['Date_N'] = pd.to_datetime(df['Release_Date'])
# Out:
# C:\Users\Aviral\AppData\Local\Temp\ipykernel_10812\1638718174.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_N'] = pd.to_datetime(df['Release_Date'])

# %%
df.drop('Date_N', axis=1, inplace=True)
# to remove columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
#  11  Data_N        7777 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(11)
# memory usage: 790.9+ KB

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Data_N          datetime64[ns]
# dtype: object

# %%
# dt.year.values_counts()     It counts the occurence of all indiviual years in date column

df['Data_N'].dt.year.value_counts()
# Out:
# Data_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
#Bar Graph
df['Data_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Data_N'>

# %%
# Question 3 : How many Movies & TV Shows are in dataset ? Show with graph

#1. GroupBy() Function

df.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Data_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
df.groupby('Category')

# %%
df.groupby('Category').Category.count()                   # To group all unique items of columns and show there count
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#Show with Bar Graph

#Countplot
#To show the count of all Unique values of any column in the form of bar graph
import matplotlib.pyplot as plt
ax = sns.countplot(x = 'Category',data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#Question 4 : Show all Movies that were release in year 2000 ? 

#1. Creating New Columns
df['Year'] = df['Data_N'].dt.year

# %%
df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
# 2      R     78 min                Horror Movies, International Movies
#
#                                          Description     Data_N    Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# ...

# %%
#2. Filtering 

df[(df['Category'] == 'Movie') & (df['Year'] == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Data_N, Year]
# Index: []

# %%
#No movies released
#so we will check in different Year
df[(df['Category'] == 'Movie') & (df['Year'] == 2020)]
# Out:
#      Show_Id Category                                    Title  \
# 4         s5    Movie                                       21
# 6         s7    Movie                                      122
# 14       s15    Movie                                     3022
# 27       s28    Movie                                   #Alive
# 28       s29    Movie            #AnneFrank - Parallel Stories
# ...      ...      ...                                      ...
# 7762   s7761    Movie                                Zaki Chan
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7786   s7785    Movie                        Zulu Man in Japan
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          Director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# ...

# %%
#Question 5: Show only the titles all TV Shows that were released in India Only 

#Filtering

df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country Release_Date  \
# ...

# %%
# Above Query shows only Tv Shows and Country we need Titles as well

df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
#To show Multiple reocrds
df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')] ['Director'],['Rating'],['Title']
# Out:
# (86              NaN
#  132     Nizar Shafi
#  340             NaN
#  364             NaN
#  533             NaN
#             ...
#  6249            NaN
#  6400            NaN
#  6469            NaN
#  7294            NaN
#  7705            NaN
#  Name: Director, Length: 71, dtype: object,
#  ['Rating'],
#  ['Title'])

# %%
#Question 6 : Show top 10 Directors who gave the highest number of TV Shows & Movies to Netflix ?
#1. Value Count 

df['Director'].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Vibhu Virender Puri        1
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %%
df['Director'].value_counts().head(15)  #head will shows top 15 count
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Lance Bangs                8
# Kunle Afolayan             8
# Ryan Polito                8
# Shannon Hartman            8
# Johnnie To                 8
# Name: count, dtype: int64

# %%
# Question 7 :  Show all the Records where "Category is Movie and Type is Comedies" or "Country is United Kingdom"

#Filtering (AND, OR OPERATORS)

df[(df['Category'] =='Movie') & (df['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
df[(df['Category'] =='Movie') & (df['Type'] == 'Comedies') | (df['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
# Question 8 : In How many Movies / Shows. Tom Cruise was Cast?

df['Cast'] == 'Tom Cruise'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7784    False
# 7785    False
# 7786    False
# 7787    False
# 7788    False
# Name: Cast, Length: 7787, dtype: bool

# %%
df[df['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Data_N, Year]
# Index: []

# %%
df_new= df.dropna() # It drops the rows that contains all Null Values

# %%
df_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Data_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
# str.contains
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5071     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description     Data_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#Question 9 : What are the different Ratings defined by Netflix ?

#nunique()
df['Rating'].nunique()
# Out:
# 14

# %%
#Unique()
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#9.2 How many Movies got the TV-14 RATING, IN CANADA ?

df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14')].shape
# Out:
# (1272, 13)

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')].shape
# Out:
# (11, 13)

# %%
#Question 9.3 How many TV Show got the 'R' rating after year 2018?

df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R') & (df['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description     Data_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
# Question 10. What is the maximum duration of a Movie/Show on Netflix ?

df.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
# data.duration.dtypes

df.Duration.dtypes
# Out:
# dtype('O')

# %%
#str.split()

df[['Minutes', 'Unit']] = df['Duration'].str.split(' ',expand = True)

# %%
df.head(2)
# Out:
#   Show_Id Category Title           Director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico    23-Dec-16
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description     Data_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
#
#   Minutes     Unit
# 0       4  Seasons
# 1      93      min

# %%
df['Minutes'].max()
# Out:
# '99'

# %%
df['Minutes'].min()
# Out:
# '1'

# %%
df['Minutes'].mean()
# Out:
# inf

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Data_N          datetime64[ns]
# Year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %%
#Questions 11: Which individual country has the highest No. of TV Shows ?

df_tvshow= df[df['Category'] == 'TV Show']

# %%
df_tvshow.head(2)
# Out:
#   Show_Id Category Title     Director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil    14-Aug-20
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     1-Jul-17
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5  TV-MA   1 Season    International TV Shows, TV Dramas, TV Mysteries
#
#                                          Description     Data_N    Year  \
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020.0
# 5  A genetics professor experiments with a treatm... 2017-07-01  2017.0
#
#   Minutes     Unit
# 0       4  Seasons
# 5       1   Season

# %%
df_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
df_tvshow.Country.value_counts().head(2)
# Out:
# Country
# United States     705
# United Kingdom    204
# Name: count, dtype: int64

# %%
# Question 12:  How can we sort dataset by Year?

df.sort_values(by = 'Year')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# ...

# %%
df.sort_values(by='Year', ascending =False).head(10)
# Out:
#      Show_Id Category                                              Title  \
# 5564   s5564    Movie                                    Sherlock Holmes
# 5919   s5919    Movie                                          Surf's Up
# 980     s981  TV Show                                       Bling Empire
# 5955   s5955    Movie                                   Taare Zameen Par
# 366     s367    Movie                                          Al acecho
# 560     s561    Movie                                           Apaharan
# 1355   s1356    Movie  Chris Rock Total Blackout: The Tamborine Exten...
# 5922   s5922  TV Show                                    Surviving Death
# 4269   s4270    Movie                                                Mud
# 2799   s2800    Movie                                               Hook
#
#                      Director  \
# 5564              Guy Ritchie
# 5919  Ash Brannon, Chris Buck
# 980                       NaN
# 5955               Aamir Khan
# ...

# %%
#Question 13 : Find all instances where Category is Movie and type is Dramas
#or category is TV Shows & Type is Kids TV

df[(df['Category']=='Movie') & (df['Type']=='Dramas')].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#   Release_Date Rating Duration    Type  \
# 4     1-Jan-20  PG-13  123 min  Dramas
# 7     1-Nov-19      R  119 min  Dramas
#
#                                          Description     Data_N    Year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#   Minutes Unit
# 4     123  min
# 7     119  min

# %%
df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")].head(2)

#kIDS TV we need to whenever element in single quotes we have to use double quotes
# Out:
#     Show_Id Category         Title     Director  \
# 111    s112  TV Show       44 Cats          NaN
# 276    s277  TV Show  Abby Hatcher  Kyran Kelly
#
#                                                   Cast                Country  \
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#     Release_Date Rating   Duration      Type  \
# 111     1-Oct-20  TV-Y7  2 Seasons  Kids' TV
# 276     1-Jul-20   TV-Y   1 Season  Kids' TV
#
#                                            Description     Data_N    Year  \
# 111  Paw-esome tales abound when singing furry frie... 2020-10-01  2020.0
# 276  A big-hearted girl helps her Fuzzly friends wh... 2020-07-01  2020.0
#
#     Minutes     Unit
# 111       2  Seasons
# 276       1   Season

# %%
#Combine both Queries 

df[(df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
